# %% [markdown]
# # **Importing Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Importing Moment Test data Sets**

# %%
test1=pd.read_csv('/content/Moment data/test1.csv',sep=',', names=['data_points1'])
test2=pd.read_csv('/content/Moment data/test2.csv',sep=',', names=['data_points2'])
test3=pd.read_csv('/content/Moment data/test3.csv',sep=',', names=['data_points3'])
test4=pd.read_csv('/content/Moment data/test4.csv',sep=',', names=['data_points4'])
test5=pd.read_csv('/content/Moment data/test5.csv',sep=',', names=['data_points5'])

# %%
## head() is used to show first 5 recoeds 
test1.head()
# Out:
#    data_points1
# 0            14
# 1            12
# 2            15
# 3            14
# 4            13

# %%
## To Know about the shape of data
test1.shape
# Out:
# (59993, 1)

# %%
## It will check null values in our data
test1.isnull().sum()
# Out:
# data_points1    0
# dtype: int64

# %%
## To Describe the data 
test1.describe()
# Out:
#        data_points1
# count  59993.000000
# mean      48.476322
# std       20.989142
# min        0.000000
# 25%       42.000000
# 50%       52.000000
# 75%       62.000000
# max       76.000000

# %% [markdown]
# ##In our test1 data we have 59993 data points and there is no null values

# %%
## Checkin the Moment in test1 data 
from matplotlib import rcParams
rcParams['figure.figsize'] = 50,15
plt.plot(test1[0:59993])
plt.ylim(0,80);

# %% [markdown]
# ##The above plot cleatly says that there is a Moment present in the test1 data

# %%
## head() is used to show first 5 recoeds 
test2.head()
# Out:
#    data_points2
# 0            52
# 1            53
# 2            56
# 3            54
# 4            53

# %%
test2.shape
# Out:
# (59996, 1)

# %%
test2.isnull().sum()
# Out:
# data_points2    0
# dtype: int64

# %% [markdown]
# ##In our test2 data we have 59996 data points and there is no null values

# %%
## Checkin the Moment in test2 data
rcParams['figure.figsize'] = 50,15
plt.plot(test2[0:59996])
plt.ylim(0,80);

# %% [markdown]
# ##The above plot saying that there is a Moment present between 5000-6000 data points and 35000-40000 data points in the test2 data

# %%
test3.head()
# Out:
#    data_points3
# 0            38
# 1            38
# 2            43
# 3            41
# 4            37

# %%
test3.shape
# Out:
# (59993, 1)

# %%
test3.isnull().sum()
# Out:
# data_points3    0
# dtype: int64

# %% [markdown]
# ##In our test3 data we have 59993 data points and there is no null values

# %%
## Checkin the Moment in test3 data
rcParams['figure.figsize'] = 50,15
plt.plot(test3[0:59993])
plt.ylim(0,80);

# %% [markdown]
# ##The above plot saying that there is a Moment present between 10000-12000 data points,30000-35000 and 55000-59993 data points approximately in the test3 data

# %%
test4.head()
# Out:
#    data_points4
# 0            57
# 1            55
# 2            54
# 3            53
# 4            52

# %%
test4.shape
# Out:
# (59993, 1)

# %%
test4.isnull().sum()
# Out:
# data_points4    0
# dtype: int64

# %% [markdown]
# ##In our test4 data we have 59993 data points and there is no null values

# %%
## Checkin the Moment in test4 data
rcParams['figure.figsize'] = 50,15
plt.plot(test4[0:59993])
plt.ylim(0,80);

# %% [markdown]
# ##The above plot saying that there is a Moment present between 10000-12000 data points,35000-42000 and 55000-59993 data points approximately in the test4 data

# %%
test5.head()
# Out:
#    data_points5
# 0            50
# 1            51
# 2            53
# 3            54
# 4            54

# %%
test5.shape
# Out:
# (59995, 1)

# %%
test5.isnull().sum()
# Out:
# data_points5    0
# dtype: int64

# %% [markdown]
# ##In our test5 data we have 59995 data points and there is no null values

# %%
## Checkin the Moment in test5 data
rcParams['figure.figsize'] = 50,15
plt.plot(test5[0:59993])
plt.ylim(0,80);

# %% [markdown]
# ##The above plot saying that there is a Moment present between 9000-15000 data points,20000-23000 and 51000-55000 data points approximately in the test5 data

# %% [markdown]
# ##Conclusion :
#
# ##test1 data has Moment
# ##test2 data has moment (Partial)
# ##test3 data has moment (Partial)
# ##test4 data has moment (Partial)
# ##test5 data has moment (Partial)
